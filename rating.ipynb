# %%
import pandas as pd
from textblob import TextBlob
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\AAYUSHI\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\AAYUSHI\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\aayushi\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1; python_version >= "3" in c:\users\aayushi\anaconda3\lib\site-packages (from textblob) (3.5)
# Requirement already satisfied: click in c:\users\aayushi\anaconda3\lib\site-packages (from nltk>=3.1; python_version >= "3"->textblob) (7.1.2)
# Requirement already satisfied: joblib in c:\users\aayushi\anaconda3\lib\site-packages (from nltk>=3.1; python_version >= "3"->textblob) (0.16.0)
# Requirement already satisfied: regex in c:\users\aayushi\anaconda3\lib\site-packages (from nltk>=3.1; python_version >= "3"->textblob) (2020.6.8)
# Requirement already satisfied: tqdm in c:\users\aayushi\anaconda3\lib\site-packages (from nltk>=3.1; python_version >= "3"->textblob) (4.47.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv("cloths-rating.csv")
df.head()
# Out:
#    ProductID                UserID  Rating  \
# 0        777  AV1YnR7wglJLPUi8IJmi       4
# 1        767  AVpfpK8KLJeJML43BCuD       4
# 2       1080  AVqkIdntQMlgsOJE6fuB       5
# 3       1077  AVpfpK8KLJeJML43BCuD       3
# 4       1049  AVpfpK8KLJeJML43BCuD       5
#
#                                                 Text
# 0                      Great taffy at a great price.
# 1  Absolutely wonderful - silky and sexy and comf...
# 2                 Love this dress! it's sooo pretty.
# 3  I had such high hopes for this dress and reall...
# 4  I love, love, love this jumpsuit. it's fun, fl...

# %%
import string
def token_words(text):
    tokens=word_tokenize(text) 
    p=PorterStemmer()
    filtered=[]
    filtered_sentence=[]
    stop_words = set(stopwords.words('english'))
    for w in tokens:
        if w not in stop_words:
            filtered_sentence.append(w.lower())
    for i in filtered_sentence:
        filtered.append(p.stem(i))
    return filtered
df['filtered_text']=df['Text'].apply(token_words)
df
# Out:
#      ProductID                UserID  Rating  \
# 0          777  AV1YnR7wglJLPUi8IJmi       4
# 1          767  AVpfpK8KLJeJML43BCuD       4
# 2         1080  AVqkIdntQMlgsOJE6fuB       5
# 3         1077  AVpfpK8KLJeJML43BCuD       3
# 4         1049  AVpfpK8KLJeJML43BCuD       5
# ..         ...                   ...     ...
# 629        823            B08GWV3SM6       1
# 630        823            B08GWV3SM6       3
# 631        847            B08GWV3SM6       5
# 632        910  AVph0EeEilAPnD_x9myq       3
# 633        333  AVqkIdntQMlgsOJE6fuB       5
#
#                                                   Text  \
# 0                        Great taffy at a great price.
# 1    Absolutely wonderful - silky and sexy and comf...
# 2                   Love this dress! it's sooo pretty.
# 3    I had such high hopes for this dress and reall...
# 4    I love, love, love this jumpsuit. it's fun, fl...
# ..                                                 ...
# 629  I placed order 4+1 soaps.But I have received w...
# 630  The soap is ok for bathing, no scent at all, m...
# 631  For a long time I was searching for Indian soa...
# 632                                 Good but not great
# 633                    Quick,easy to make & tasty too.
#
#                                          filtered_text
# 0                      [great, taffi, great, price, .]
# 1           [absolut, wonder, -, silki, sexi, comfort]
# 2                [love, dress, !, 's, sooo, pretti, .]
# 3        [i, high, hope, dress, realli, want, work, .]
# 4    [i, love, ,, love, ,, love, jumpsuit, ., 's, f...
# ..                                                 ...
# 629  [i, place, order, 4+1, soaps.but, i, receiv, w...
# 630  [the, soap, ok, bath, ,, scent, ,, drier, ., t...
# 631  [for, long, time, i, search, indian, soap, equ...
# 632                                      [good, great]
# 633                [quick, ,, easi, make, &, tasti, .]
#
# [634 rows x 5 columns]

# %%
import json
with open('contractions.json', 'r') as f:
    contractions_dict = json.load(f)
contractions = contractions_dict

# %%
import re

def process_text(text):
    text=text.lower()
    text = re.sub(r"\d+", " ", str(text))
    text = re.sub(r"\b[a-zA-Z]\b", "", str(text))
    for word in text.split():
        if word.lower() in contractions:
            text = text.replace(word, contractions[word.lower()])
    text = re.sub(r"\s+", " ", str(text))
    text = re.sub('&quot;'," ", text)
    text = re.sub(r"[^\w\s]", " ", str(text))
    stop_words = set(stopwords.words('english'))
    filtered_sentence = []
    for w in text:
        if w not in stop_words:
            filtered_sentence.append(w)
    return text
df['processed_text']= df['Text'].apply(process_text)
df
# Out:
#      ProductID                UserID  Rating  \
# 0          777  AV1YnR7wglJLPUi8IJmi       4
# 1          767  AVpfpK8KLJeJML43BCuD       4
# 2         1080  AVqkIdntQMlgsOJE6fuB       5
# 3         1077  AVpfpK8KLJeJML43BCuD       3
# 4         1049  AVpfpK8KLJeJML43BCuD       5
# ..         ...                   ...     ...
# 629        823            B08GWV3SM6       1
# 630        823            B08GWV3SM6       3
# 631        847            B08GWV3SM6       5
# 632        910  AVph0EeEilAPnD_x9myq       3
# 633        333  AVqkIdntQMlgsOJE6fuB       5
#
#                                                   Text  \
# 0                        Great taffy at a great price.
# 1    Absolutely wonderful - silky and sexy and comf...
# 2                   Love this dress! it's sooo pretty.
# 3    I had such high hopes for this dress and reall...
# 4    I love, love, love this jumpsuit. it's fun, fl...
# ..                                                 ...
# 629  I placed order 4+1 soaps.But I have received w...
# 630  The soap is ok for bathing, no scent at all, m...
# 631  For a long time I was searching for Indian soa...
# 632                                 Good but not great
# 633                    Quick,easy to make & tasty too.
#
#                                          filtered_text  \
# 0                      [great, taffi, great, price, .]
# 1           [absolut, wonder, -, silki, sexi, comfort]
# 2                [love, dress, !, 's, sooo, pretti, .]
# 3        [i, high, hope, dress, realli, want, work, .]
# 4    [i, love, ,, love, ,, love, jumpsuit, ., 's, f...
# ..                                                 ...
# 629  [i, place, order, 4+1, soaps.but, i, receiv, w...
# 630  [the, soap, ok, bath, ,, scent, ,, drier, ., t...
# 631  [for, long, time, i, search, indian, soap, equ...
# 632                                      [good, great]
# 633                [quick, ,, easi, make, &, tasti, .]
#
#                                         processed_text
# 0                          great taffy at great price
# 1    absolutely wonderful   silky and sexy and comf...
# 2                    love this dress  it  sooo pretty
# 3     had such high hopes for this dress and really...
# 4     love  love  love this jumpsuit  it  fun  flir...
# ..                                                 ...
# 629   placed order   soaps but have received withou...
# 630  the soap is ok for bathing  no scent at all  m...
# 631  for long time was searching for indian soap eq...
# 632                                 good but not great
# 633                    quick easy to make   tasty too
#
# [634 rows x 6 columns]

# %%
def sentiment(text):
    try:
        return TextBlob(str(text)).sentiment.polarity
    except:
        return None
df['sentiment']= df['filtered_text'].apply(sentiment)
df
# Out:
#      ProductID                UserID  Rating  \
# 0          777  AV1YnR7wglJLPUi8IJmi       4
# 1          767  AVpfpK8KLJeJML43BCuD       4
# 2         1080  AVqkIdntQMlgsOJE6fuB       5
# 3         1077  AVpfpK8KLJeJML43BCuD       3
# 4         1049  AVpfpK8KLJeJML43BCuD       5
# ..         ...                   ...     ...
# 629        823            B08GWV3SM6       1
# 630        823            B08GWV3SM6       3
# 631        847            B08GWV3SM6       5
# 632        910  AVph0EeEilAPnD_x9myq       3
# 633        333  AVqkIdntQMlgsOJE6fuB       5
#
#                                                   Text  \
# 0                        Great taffy at a great price.
# 1    Absolutely wonderful - silky and sexy and comf...
# 2                   Love this dress! it's sooo pretty.
# 3    I had such high hopes for this dress and reall...
# 4    I love, love, love this jumpsuit. it's fun, fl...
# ..                                                 ...
# 629  I placed order 4+1 soaps.But I have received w...
# 630  The soap is ok for bathing, no scent at all, m...
# 631  For a long time I was searching for Indian soa...
# 632                                 Good but not great
# 633                    Quick,easy to make & tasty too.
#
#                                          filtered_text  \
# 0                      [great, taffi, great, price, .]
# 1           [absolut, wonder, -, silki, sexi, comfort]
# 2                [love, dress, !, 's, sooo, pretti, .]
# 3        [i, high, hope, dress, realli, want, work, .]
# 4    [i, love, ,, love, ,, love, jumpsuit, ., 's, f...
# ..                                                 ...
# 629  [i, place, order, 4+1, soaps.but, i, receiv, w...
# 630  [the, soap, ok, bath, ,, scent, ,, drier, ., t...
# 631  [for, long, time, i, search, indian, soap, equ...
# 632                                      [good, great]
# 633                [quick, ,, easi, make, &, tasti, .]
#
#                                         processed_text  sentiment
# 0                          great taffy at great price    0.800000
# 1    absolutely wonderful   silky and sexy and comf...   0.000000
# 2                    love this dress  it  sooo pretty    0.625000
# 3     had such high hopes for this dress and really...   0.160000
# 4     love  love  love this jumpsuit  it  fun  flir...   0.575000
# ..                                                 ...        ...
# 629   placed order   soaps but have received withou...   0.000000
# 630  the soap is ok for bathing  no scent at all  m...   0.266667
# 631  for long time was searching for indian soap eq...  -0.025000
# 632                                 good but not great   0.750000
# 633                    quick easy to make   tasty too    0.333333
#
# [634 rows x 7 columns]

# %%
df['Updated_score']=df['Rating']*df['sentiment']
df
# Out:
#      ProductID                UserID  Rating  \
# 0          777  AV1YnR7wglJLPUi8IJmi       4
# 1          767  AVpfpK8KLJeJML43BCuD       4
# 2         1080  AVqkIdntQMlgsOJE6fuB       5
# 3         1077  AVpfpK8KLJeJML43BCuD       3
# 4         1049  AVpfpK8KLJeJML43BCuD       5
# ..         ...                   ...     ...
# 629        823            B08GWV3SM6       1
# 630        823            B08GWV3SM6       3
# 631        847            B08GWV3SM6       5
# 632        910  AVph0EeEilAPnD_x9myq       3
# 633        333  AVqkIdntQMlgsOJE6fuB       5
#
#                                                   Text  \
# 0                        Great taffy at a great price.
# 1    Absolutely wonderful - silky and sexy and comf...
# 2                   Love this dress! it's sooo pretty.
# 3    I had such high hopes for this dress and reall...
# 4    I love, love, love this jumpsuit. it's fun, fl...
# ..                                                 ...
# 629  I placed order 4+1 soaps.But I have received w...
# 630  The soap is ok for bathing, no scent at all, m...
# 631  For a long time I was searching for Indian soa...
# 632                                 Good but not great
# 633                    Quick,easy to make & tasty too.
#
#                                          filtered_text  \
# 0                      [great, taffi, great, price, .]
# 1           [absolut, wonder, -, silki, sexi, comfort]
# 2                [love, dress, !, 's, sooo, pretti, .]
# 3        [i, high, hope, dress, realli, want, work, .]
# 4    [i, love, ,, love, ,, love, jumpsuit, ., 's, f...
# ..                                                 ...
# 629  [i, place, order, 4+1, soaps.but, i, receiv, w...
# 630  [the, soap, ok, bath, ,, scent, ,, drier, ., t...
# 631  [for, long, time, i, search, indian, soap, equ...
# 632                                      [good, great]
# 633                [quick, ,, easi, make, &, tasti, .]
#
#                                         processed_text  sentiment  \
# 0                          great taffy at great price    0.800000
# 1    absolutely wonderful   silky and sexy and comf...   0.000000
# 2                    love this dress  it  sooo pretty    0.625000
# 3     had such high hopes for this dress and really...   0.160000
# 4     love  love  love this jumpsuit  it  fun  flir...   0.575000
# ..                                                 ...        ...
# 629   placed order   soaps but have received withou...   0.000000
# 630  the soap is ok for bathing  no scent at all  m...   0.266667
# 631  for long time was searching for indian soap eq...  -0.025000
# 632                                 good but not great   0.750000
# 633                    quick easy to make   tasty too    0.333333
#
#      Updated_score
# 0         3.200000
# 1         0.000000
# 2         3.125000
# 3         0.480000
# 4         2.875000
# ..             ...
# 629       0.000000
# 630       0.800000
# 631      -0.125000
# 632       2.250000
# 633       1.666667
#
# [634 rows x 8 columns]

# %%
def classify_scores(rate):
    if rate<=0:
        return 1
    elif rate<=2:
        return 2
    elif rate<=3:
        return 3
    elif rate<=4:
        return 4
    elif rate<=5:
        return 5

df['New_score']=df['Updated_score'].apply(classify_scores)
df
# Out:
#      ProductID                UserID  Rating  \
# 0          777  AV1YnR7wglJLPUi8IJmi       4
# 1          767  AVpfpK8KLJeJML43BCuD       4
# 2         1080  AVqkIdntQMlgsOJE6fuB       5
# 3         1077  AVpfpK8KLJeJML43BCuD       3
# 4         1049  AVpfpK8KLJeJML43BCuD       5
# ..         ...                   ...     ...
# 629        823            B08GWV3SM6       1
# 630        823            B08GWV3SM6       3
# 631        847            B08GWV3SM6       5
# 632        910  AVph0EeEilAPnD_x9myq       3
# 633        333  AVqkIdntQMlgsOJE6fuB       5
#
#                                                   Text  \
# 0                        Great taffy at a great price.
# 1    Absolutely wonderful - silky and sexy and comf...
# 2                   Love this dress! it's sooo pretty.
# 3    I had such high hopes for this dress and reall...
# 4    I love, love, love this jumpsuit. it's fun, fl...
# ..                                                 ...
# 629  I placed order 4+1 soaps.But I have received w...
# 630  The soap is ok for bathing, no scent at all, m...
# 631  For a long time I was searching for Indian soa...
# 632                                 Good but not great
# 633                    Quick,easy to make & tasty too.
#
#                                          filtered_text  \
# 0                      [great, taffi, great, price, .]
# 1           [absolut, wonder, -, silki, sexi, comfort]
# 2                [love, dress, !, 's, sooo, pretti, .]
# 3        [i, high, hope, dress, realli, want, work, .]
# 4    [i, love, ,, love, ,, love, jumpsuit, ., 's, f...
# ..                                                 ...
# 629  [i, place, order, 4+1, soaps.but, i, receiv, w...
# 630  [the, soap, ok, bath, ,, scent, ,, drier, ., t...
# 631  [for, long, time, i, search, indian, soap, equ...
# 632                                      [good, great]
# 633                [quick, ,, easi, make, &, tasti, .]
#
#                                         processed_text  sentiment  \
# 0                          great taffy at great price    0.800000
# 1    absolutely wonderful   silky and sexy and comf...   0.000000
# 2                    love this dress  it  sooo pretty    0.625000
# 3     had such high hopes for this dress and really...   0.160000
# 4     love  love  love this jumpsuit  it  fun  flir...   0.575000
# ..                                                 ...        ...
# 629   placed order   soaps but have received withou...   0.000000
# 630  the soap is ok for bathing  no scent at all  m...   0.266667
# 631  for long time was searching for indian soap eq...  -0.025000
# 632                                 good but not great   0.750000
# 633                    quick easy to make   tasty too    0.333333
#
#      Updated_score  New_score
# 0         3.200000          4
# 1         0.000000          1
# 2         3.125000          4
# 3         0.480000          2
# 4         2.875000          3
# ..             ...        ...
# 629       0.000000          1
# 630       0.800000          2
# 631      -0.125000          1
# 632       2.250000          3
# 633       1.666667          2
#
# [634 rows x 9 columns]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
#df['UserID']=le.fit_transform(df['UserID'])
#df['ProductID']=le.fit_transform(df['ProductID'])
df
# Out:
#      ProductID                UserID  Rating  \
# 0          777  AV1YnR7wglJLPUi8IJmi       4
# 1          767  AVpfpK8KLJeJML43BCuD       4
# 2         1080  AVqkIdntQMlgsOJE6fuB       5
# 3         1077  AVpfpK8KLJeJML43BCuD       3
# 4         1049  AVpfpK8KLJeJML43BCuD       5
# ..         ...                   ...     ...
# 629        823            B08GWV3SM6       1
# 630        823            B08GWV3SM6       3
# 631        847            B08GWV3SM6       5
# 632        910  AVph0EeEilAPnD_x9myq       3
# 633        333  AVqkIdntQMlgsOJE6fuB       5
#
#                                                   Text  \
# 0                        Great taffy at a great price.
# 1    Absolutely wonderful - silky and sexy and comf...
# 2                   Love this dress! it's sooo pretty.
# 3    I had such high hopes for this dress and reall...
# 4    I love, love, love this jumpsuit. it's fun, fl...
# ..                                                 ...
# 629  I placed order 4+1 soaps.But I have received w...
# 630  The soap is ok for bathing, no scent at all, m...
# 631  For a long time I was searching for Indian soa...
# 632                                 Good but not great
# 633                    Quick,easy to make & tasty too.
#
#                                          filtered_text  \
# 0                      [great, taffi, great, price, .]
# 1           [absolut, wonder, -, silki, sexi, comfort]
# 2                [love, dress, !, 's, sooo, pretti, .]
# 3        [i, high, hope, dress, realli, want, work, .]
# 4    [i, love, ,, love, ,, love, jumpsuit, ., 's, f...
# ..                                                 ...
# 629  [i, place, order, 4+1, soaps.but, i, receiv, w...
# 630  [the, soap, ok, bath, ,, scent, ,, drier, ., t...
# 631  [for, long, time, i, search, indian, soap, equ...
# 632                                      [good, great]
# 633                [quick, ,, easi, make, &, tasti, .]
#
#                                         processed_text  sentiment  \
# 0                          great taffy at great price    0.800000
# 1    absolutely wonderful   silky and sexy and comf...   0.000000
# 2                    love this dress  it  sooo pretty    0.625000
# 3     had such high hopes for this dress and really...   0.160000
# 4     love  love  love this jumpsuit  it  fun  flir...   0.575000
# ..                                                 ...        ...
# 629   placed order   soaps but have received withou...   0.000000
# 630  the soap is ok for bathing  no scent at all  m...   0.266667
# 631  for long time was searching for indian soap eq...  -0.025000
# 632                                 good but not great   0.750000
# 633                    quick easy to make   tasty too    0.333333
#
#      Updated_score  New_score
# 0         3.200000          4
# 1         0.000000          1
# 2         3.125000          4
# 3         0.480000          2
# 4         2.875000          3
# ..             ...        ...
# 629       0.000000          1
# 630       0.800000          2
# 631      -0.125000          1
# 632       2.250000          3
# 633       1.666667          2
#
# [634 rows x 9 columns]

# %%
df_pivot=df.pivot_table(index='ProductID',columns='UserID',values='Rating').fillna(0)
df_pivot
# Out:
# UserID     AV1YnR7wglJLPUi8IJmi  AVpfIfGA1cnluZ0-emyp  AVpf_4sUilAPnD_xlwYV  \
# ProductID
# 89                          0.0              0.000000              0.000000
# 333                         0.0              5.000000              0.000000
# 369                         5.0              3.000000              0.000000
# 444                         2.0              5.000000              0.000000
# 684                         0.0              0.000000              5.000000
# 697                         0.0              1.000000              1.000000
# 767                         2.0              0.000000              0.000000
# 777                         4.0              0.000000              0.000000
# 823                         0.0              0.000000              0.000000
# 847                         0.0              0.000000              0.000000
# 853                         0.0              0.000000              5.000000
# 858                         0.0              0.000000              0.000000
# 862                         3.5              3.666667              0.000000
# 910                         0.0              4.666667              0.000000
# 949                         5.0              4.750000              4.500000
# 1002                        5.0              5.000000              1.000000
# 1003                        0.0              0.000000              0.000000
# 1049                        5.0              4.000000              0.000000
# 1060                        5.0              5.000000              3.666667
# 1065                        0.0              0.000000              0.000000
# 1077                        0.0              4.000000              0.000000
# 1080                        0.0              5.000000              0.000000
# 1095                        0.0              0.000000              0.000000
# 1120                        0.0              0.000000              5.000000
# 6969                        0.0              0.000000              0.000000
# 8001                        0.0              5.000000              0.000000
# 9696                        5.0              5.000000              0.000000
#
# UserID     AVpfpK8KLJeJML43BCuD  AVpftoij1cnluZ0-p5n2  AVpfwS_CLJeJML43DH5w  \
# ProductID
# 89                          5.0                   0.0                   0.0
# 333                         0.0                   0.0                   4.0
# 369                         4.0                   0.0                   5.0
# 444                         0.0                   1.0                   0.0
# 684                         5.0                   1.0                   0.0
# 697                         0.0                   0.0                   0.0
# 767                         4.0                   0.0                   0.0
# 777                         0.0                   0.0                   0.0
# 823                         5.0                   0.0                   0.0
# 847                         2.0                   0.0                   0.0
# 853                         0.0                   0.0                   0.0
# 858                         0.0                   5.0                   0.0
# 862                         5.0                   4.5                   0.0
# 910                         0.0                   0.0                   0.0
# 949                         0.0                   0.0                   0.0
# 1002                        0.0                   0.0                   0.0
# 1003                        0.0                   0.0                   0.0
# 1049                        5.0                   0.0                   0.0
# 1060                        0.0                   1.0                   0.0
# 1065                        4.0                   0.0                   0.0
# 1077                        3.0                   1.0                   0.0
# 1080                        0.0                   1.0                   0.0
# 1095                        3.0                   3.0                   0.0
# 1120                        0.0                   0.0                   0.0
# 6969                        0.0                   0.0                   0.0
# 8001                        0.0                   0.0                   0.0
# 9696                        4.0                   0.0                   0.0
#
# UserID     AVpgdkC8ilAPnD_xsvyi  AVph0EeEilAPnD_x9myq  AVphLY7v1cnluZ0-_Ty0  \
# ProductID
# 89                         5.00              3.000000                   4.0
# 333                        0.00              0.000000                   5.0
# 369                        4.00              3.000000                   0.0
# 444                        5.00              5.000000                   2.0
# 684                        1.00              5.000000                   2.0
# 697                        5.00              0.000000                   5.0
# 767                        1.00              0.000000                   0.0
# 777                        2.00              0.000000                   0.0
# 823                        5.00              2.000000                   0.0
# 847                        5.00              4.333333                   5.0
# 853                        5.00              0.000000                   0.0
# 858                        5.00              2.000000                   5.0
# 862                        4.25              2.500000                   3.5
# 910                        4.00              4.333333                   5.0
# 949                        1.00              0.000000                   4.0
# 1002                       5.00              0.000000                   0.0
# 1003                       1.00              0.000000                   5.0
# 1049                       0.00              0.000000                   0.0
# 1060                       0.00              5.000000                   4.0
# 1065                       0.00              0.000000                   0.0
# 1077                       3.50              3.500000                   5.0
# 1080                       3.00              2.000000                   0.0
# 1095                       0.00              4.333333                   0.0
# 1120                       0.00              0.000000                   0.0
# 6969                       0.00              0.000000                   0.0
# 8001                       0.00              0.000000                   0.0
# 9696                       1.00              4.500000                   2.5
#
# UserID     AVphgVaX1cnluZ0-DR74  ...  B07MXKMWT5  B07NLR9YPZ  B07Q2B5Z9D  \
# ProductID                        ...
# 89                          0.0  ...    0.000000        4.00    0.000000
# 333                         5.0  ...    0.000000        2.00    2.666667
# 369                         0.0  ...    0.000000        0.00    0.000000
# 444                         0.0  ...    4.000000        0.00    5.000000
# 684                         0.0  ...    5.000000        0.00    5.000000
# 697                         5.0  ...    5.000000        5.00    5.000000
# 767                         0.0  ...    0.000000        5.00    0.000000
# 777                         5.0  ...    0.000000        2.00    0.000000
# 823                         0.0  ...    0.000000        5.00    0.000000
# 847                         0.0  ...    0.000000        5.00    0.000000
# 853                         0.0  ...    0.000000        0.00    0.000000
# 858                         5.0  ...    0.000000        0.00    0.000000
# 862                         0.0  ...    2.333333        4.50    5.000000
# 910                         0.0  ...    0.000000        5.00    5.000000
# 949                         0.0  ...    4.000000        0.00    5.000000
# 1002                        0.0  ...    2.000000        0.00    3.000000
# 1003                        0.0  ...    4.000000        0.00    0.000000
# 1049                        0.0  ...    0.000000        0.00    0.000000
# 1060                        0.0  ...    3.750000        0.00    3.000000
# 1065                        0.0  ...    0.000000        0.00    0.000000
# 1077                        1.0  ...    0.000000        0.00    0.000000
# 1080                        5.0  ...    0.000000        5.00    0.000000
# 1095                        5.0  ...    0.000000        0.00    0.000000
# 1120                        0.0  ...    0.000000        0.00    0.000000
# 6969                        5.0  ...    0.000000        5.00    0.000000
# 8001                        5.0  ...    0.000000        0.00    0.000000
# 9696                        2.0  ...    0.000000        4.75    0.000000
#
# UserID     B07S55SML2  B07VYRQFBJ  B0818ZYVH1  B082KY37BL  B0832PGNNH  \
# ProductID
# 89                0.0    0.000000        5.00    0.000000    0.000000
# 333               0.0    0.000000        3.50    0.000000    0.000000
# 369               0.0    0.000000        0.00    3.666667    0.000000
# 444               0.0    0.000000        3.00    0.000000    0.000000
# 684               0.0    0.000000        0.00    0.000000    0.000000
# 697               0.0    0.000000        0.00    0.000000    0.000000
# 767               0.0    5.000000        0.00    1.000000    1.000000
# 777               0.0    0.000000        0.00    5.000000    0.000000
# 823               0.0    0.000000        5.00    0.000000    0.000000
# 847               0.0    5.000000        0.00    0.000000    4.000000
# 853               0.0    4.000000        0.00    0.000000    5.000000
# 858               0.0    0.000000        0.00    0.000000    4.500000
# 862               0.0    0.000000        5.00    0.000000    0.000000
# 910               0.0    0.000000        5.00    0.000000    0.000000
# 949               0.0    0.000000        0.00    0.000000    0.000000
# 1002              0.0    0.000000        0.00    0.000000    0.000000
# 1003              0.0    0.000000        0.00    0.000000    0.000000
# 1049              0.0    0.000000        0.00    0.000000    0.000000
# 1060              0.0    0.000000        0.00    0.000000    0.000000
# 1065              0.0    5.000000        0.00    0.000000    5.000000
# 1077              0.0    3.666667        5.00    0.000000    4.166667
# 1080              0.0    2.000000        0.00    0.000000    5.000000
# 1095              5.0    0.000000        0.00    2.000000    3.000000
# 1120              0.0    3.000000        0.00    0.000000    1.000000
# 6969              0.0    0.000000        5.00    0.000000    0.000000
# 8001              0.0    0.000000        0.00    2.333333    0.000000
# 9696              0.0    0.000000        2.75    0.000000    0.000000
#
# UserID     B08DLL7C2D  B08GWV3SM6
# ProductID
# 89           0.000000        5.00
# 333          0.000000        0.00
# 369          5.000000        0.00
# 444          3.333333        0.00
# 684          0.000000        4.25
# 697          0.000000        3.50
# 767          0.000000        0.00
# 777          0.000000        0.00
# 823          0.000000        2.00
# 847          0.000000        5.00
# 853          0.000000        0.00
# 858          0.000000        0.00
# 862          0.000000        0.00
# 910          0.000000        0.00
# 949          0.000000        3.00
# 1002         0.000000        0.00
# 1003         0.000000        0.00
# 1049         0.000000        0.00
# 1060         0.000000        0.00
# 1065         0.000000        0.00
# 1077         0.000000        0.00
# 1080         0.000000        0.00
# 1095         5.000000        0.00
# 1120         0.000000        0.00
# 6969         0.000000        0.00
# 8001         3.666667        0.00
# 9696         0.000000        0.00
#
# [27 rows x 42 columns]

# %%
from scipy.sparse import csr_matrix

df_pivot_matrix = csr_matrix(df_pivot.values)
print(df_pivot_matrix)
# Out:
#   (0, 3)	5.0
#   (0, 6)	5.0
#   (0, 7)	3.0
#   (0, 8)	4.0
#   (0, 11)	5.0
#   (0, 16)	3.0
#   (0, 18)	3.8
#   (0, 20)	4.0
#   (0, 22)	5.0
#   (0, 28)	5.0
#   (0, 33)	4.0
#   (0, 37)	5.0
#   (0, 41)	5.0
#   (1, 1)	5.0
#   (1, 5)	4.0
#   (1, 8)	5.0
#   (1, 9)	5.0
#   (1, 10)	1.0
#   (1, 13)	4.666666666666667
#   (1, 17)	1.5
#   (1, 22)	5.0
#   (1, 25)	2.75
#   (1, 29)	3.0
#   (1, 33)	2.0
#   (1, 34)	2.6666666666666665
#   :	:
#   (25, 17)	5.0
#   (25, 21)	1.0
#   (25, 22)	1.0
#   (25, 25)	3.3333333333333335
#   (25, 30)	5.0
#   (25, 38)	2.3333333333333335
#   (25, 40)	3.6666666666666665
#   (26, 0)	5.0
#   (26, 1)	5.0
#   (26, 3)	4.0
#   (26, 6)	1.0
#   (26, 7)	4.5
#   (26, 8)	2.5
#   (26, 9)	2.0
#   (26, 11)	4.666666666666667
#   (26, 16)	5.0
#   (26, 17)	3.8
#   (26, 18)	3.6666666666666665
#   (26, 19)	1.0
#   (26, 22)	1.0
#   (26, 23)	4.0
#   (26, 25)	3.6666666666666665
#   (26, 28)	5.0
#   (26, 33)	4.75
#   (26, 37)	2.75

# %%
#!pip install cosine_similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity
#         0.38654317, 0.40183408, 0.16329777, 1.        , 0.        ,
#         0.        , 0.        ],
#        [0.49388562, 0.51996972, 0.12174055, 0.12637109, 0.11813098,
#         0.31267873, 0.15565773, 0.23138757, 0.45786524, 0.12368342,
#         0.01634932, 0.15864737, 0.40034406, 0.48940269, 0.12326826,
#         0.        , 0.1470871 , 0.        , 0.14439907, 0.11040161,
#         0.16685873, 0.3878871 , 0.16094154, 0.        , 1.        ,
#         0.42956366, 0.55380227],
#        [0.07737017, 0.51370258, 0.44980712, 0.42834958, 0.0606497 ,
#         0.22158983, 0.23741721, 0.33811407, 0.04326073, 0.20105197,
#         0.135594  , 0.1409733 , 0.27729352, 0.39014008, 0.37862804,
#         0.22112936, 0.09759001, 0.18122009, 0.36193581, 0.07324975,
#         0.36612775, 0.534899  , 0.53242797, 0.        , 0.42956366,
#         1.        , 0.39443137],
#        [0.63605223, 0.40396811, 0.3376436 , 0.48164069, 0.3681713 ,
#         0.23541762, 0.33005708, 0.48345747, 0.45259284, 0.29720635,
#         0.06747383, 0.36489946, 0.64551571, 0.58344029, 0.32984896,
#         0.36495771, 0.21199716, 0.43884397, 0.4776591 , 0.18259929,
#         0.40435297, 0.53615064, 0.33654028, 0.        , 0.55380227,
#         0.39443137, 1.        ]])

# %%
import numpy as np

# %%
from sklearn.neighbors import NearestNeighbors

# %%
model_knn= NearestNeighbors(metric='cosine',n_neighbors=20, radius=1)
model_knn.fit(df_pivot_matrix)
# Out:
# NearestNeighbors(metric='cosine', n_neighbors=20, radius=1)

# %% [markdown]
# 1. Data gathering
# 2. Data Analysis
# 3. data cleaning
# 4. data pre processing
#     a. Encoding
#     b. Transformation
#         b.1 Normalization
#         b.2 Standardization
# 5. Feature selection
# 6. feature building
# 7. Model Building
# 8. Evaluation

# %%
n= int(input("How many recommendation you want:"))
productID = int(input('Enter ProductID:'))
data = df_pivot.index.to_list()
data
# Out:
# How many recommendation you want:6
# Enter ProductID:333
# [89,
#  333,
#  369,
#  444,
#  684,
#  697,
#  767,
#  777,
#  823,
#  847,
#  853,
#  858,
#  862,
#  910,
#  949,
#  1002,
#  1003,
#  1049,
#  1060,
#  1065,
#  1077,
#  1080,
#  1095,
#  1120,
#  6969,
#  8001,
#  9696]

# %%
query_index = data.index(productID)
print(query_index)
# Out:
# 1

# %%
distance,indices = model_knn.kneighbors(df_pivot.iloc[query_index,:].values.reshape(1,-1), n_neighbors = n)
print(distance)
print(indices)
# Out:
# [[1.11022302e-16 4.76539823e-01 4.80030278e-01 4.86297425e-01
#   5.06055395e-01 5.83019834e-01]]
# [[ 1 13 24 25  5  2]]

# %%
type(distance)
# Out:
# numpy.ndarray

# %%
list(zip(distance.tolist()[0], indices.tolist()[0]))
# Out:
# [(1.1102230246251565e-16, 1),
#  (0.47653982322763155, 13),
#  (0.48003027815483956, 24),
#  (0.48629742490807004, 25),
#  (0.506055394749473, 5),
#  (0.5830198339876502, 2)]

# %%
i=df_pivot.index[indices.flatten()]
i
# Out:
# Int64Index([333, 910, 6969, 8001, 697, 369], dtype='int64', name='ProductID')

# %%
d= distance.flatten()
d
rd=[]
for x in d:
    x= round(x,2)
    rd.append(x)
rd
# Out:
# [0.0, 0.48, 0.48, 0.49, 0.51, 0.58]

# %%
new = list(zip(i,rd))
del new[0]
new
# Out:
# [(910, 0.48), (6969, 0.48), (8001, 0.49), (697, 0.51), (369, 0.58)]

# %%
#rating
pd.DataFrame(new)
# Out:
#       0     1
# 0   910  0.48
# 1  6969  0.48
# 2  8001  0.49
# 3   697  0.51
# 4   369  0.58

# %%
def classify_sentiment(score):
    if score<0:
        return 'negative'
    elif score==0:
        return 'neutral'
    elif score>0:
        return 'positive'

df['status']= df['sentiment'].apply(classify_sentiment)
df
# Out:
#      ProductID                UserID  Rating  \
# 0          777  AV1YnR7wglJLPUi8IJmi       4
# 1          767  AVpfpK8KLJeJML43BCuD       4
# 2         1080  AVqkIdntQMlgsOJE6fuB       5
# 3         1077  AVpfpK8KLJeJML43BCuD       3
# 4         1049  AVpfpK8KLJeJML43BCuD       5
# ..         ...                   ...     ...
# 629        823            B08GWV3SM6       1
# 630        823            B08GWV3SM6       3
# 631        847            B08GWV3SM6       5
# 632        910  AVph0EeEilAPnD_x9myq       3
# 633        333  AVqkIdntQMlgsOJE6fuB       5
#
#                                                   Text  \
# 0                        Great taffy at a great price.
# 1    Absolutely wonderful - silky and sexy and comf...
# 2                   Love this dress! it's sooo pretty.
# 3    I had such high hopes for this dress and reall...
# 4    I love, love, love this jumpsuit. it's fun, fl...
# ..                                                 ...
# 629  I placed order 4+1 soaps.But I have received w...
# 630  The soap is ok for bathing, no scent at all, m...
# 631  For a long time I was searching for Indian soa...
# 632                                 Good but not great
# 633                    Quick,easy to make & tasty too.
#
#                                          filtered_text  \
# 0                      [great, taffi, great, price, .]
# 1           [absolut, wonder, -, silki, sexi, comfort]
# 2                [love, dress, !, 's, sooo, pretti, .]
# 3        [i, high, hope, dress, realli, want, work, .]
# 4    [i, love, ,, love, ,, love, jumpsuit, ., 's, f...
# ..                                                 ...
# 629  [i, place, order, 4+1, soaps.but, i, receiv, w...
# 630  [the, soap, ok, bath, ,, scent, ,, drier, ., t...
# 631  [for, long, time, i, search, indian, soap, equ...
# 632                                      [good, great]
# 633                [quick, ,, easi, make, &, tasti, .]
#
#                                         processed_text  sentiment  \
# 0                          great taffy at great price    0.800000
# 1    absolutely wonderful   silky and sexy and comf...   0.000000
# 2                    love this dress  it  sooo pretty    0.625000
# 3     had such high hopes for this dress and really...   0.160000
# 4     love  love  love this jumpsuit  it  fun  flir...   0.575000
# ..                                                 ...        ...
# 629   placed order   soaps but have received withou...   0.000000
# 630  the soap is ok for bathing  no scent at all  m...   0.266667
# 631  for long time was searching for indian soap eq...  -0.025000
# 632                                 good but not great   0.750000
# 633                    quick easy to make   tasty too    0.333333
#
#      Updated_score  New_score    status
# 0         3.200000          4  positive
# 1         0.000000          1   neutral
# 2         3.125000          4  positive
# 3         0.480000          2  positive
# 4         2.875000          3  positive
# ..             ...        ...       ...
# 629       0.000000          1   neutral
# 630       0.800000          2  positive
# 631      -0.125000          1  negative
# 632       2.250000          3  positive
# 633       1.666667          2  positive
#
# [634 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
status= df['status'].value_counts()
label =[]
plt.pie(status, labels=status.index.tolist(), autopct='%.2f%%')
plt.show()

# %%
len(df.ProductID.unique())
# Out:
# 27
